# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("hotels.csv")

# %%
df.sample(10)
# Out:
#                       name reviews  rating  \
# 97        Room Mate Gerard       4     5.0
# 0       Hotel Cotton House      49     4.5
# 71  Novotel Barcelona City      13     4.0
# 99       Tryp  Apolo Hotel      34     3.0
# 54              Hotel Cram      12     4.5
# 32          Banys Oriental      12     4.5
# 29   The Barcelona EDITION      21     4.0
# 95     Holiday Inn Express      15     3.5
# 18              Casa Bonay      14     4.5
# 98                    Axel      31     3.0
#
#                                  address         postcode  price range  \
# 97               Carrer Ausiàs March, 34  08010 Barcelona   Medium-Low
# 0   Gran Via de les Corts Catalanes, 670  08010 Barcelona  Medium-High
# 71                 Avenida Diagonal, 201  08018 Barcelona   Medium-Low
# 99          Avinguda del Paraŀlel, 57-59  08004 Barcelona   Medium-Low
# 54                   Carrer d'Aribau, 54  08011 Barcelona  Medium-High
# ...

# %%
df
# Out:
#                         name reviews  rating  \
# 0         Hotel Cotton House      49     4.5
# 1               Villa Emilia      25     5.0
# 2             Alma Barcelona      28     4.5
# 3                 Hotel 1898      77     4.5
# 4                 The Serras      14     5.0
# ..                       ...     ...     ...
# 105               ABaC Hotel       4     5.0
# 106            Hotel Astoria       8     4.0
# 107     Hotel Regencia Colon       8     4.0
# 108           Praktik Garden      13     3.5
# 109  Hotel Negresco Princess      11     3.5
#
#                                   address         postcode  price range  \
# 0    Gran Via de les Corts Catalanes, 670  08010 Barcelona  Medium-High
# 1                 Carrer de Calàbria, 115  08015 Barcelona   Medium-Low
# 2                 Carrer de Mallorca, 271  08008 Barcelona  Medium-High
# 3                          La Rambla, 109  08002 Barcelona  Medium-High
# ...

# %%
df.isna().sum()
# Out:
# name           0
# reviews        0
# rating         0
# address        0
# postcode       0
# price range    6
# amenities      0
# dtype: int64

# %%
df[df['price range'] == 'Medium-Low']
# Out:
#                                            name reviews  rating  \
# 1                                  Villa Emilia      25     5.0
# 5                                 Barceló Raval      54     4.5
# 10                                           Do      13     4.5
# 11                           Pulitzer Barcelona      40     4.0
# 14                    Hotel Barcelona Universal      41     4.0
# 17                                       Wilson      10     5.0
# 18                                   Casa Bonay      14     4.5
# 19             Renaissance Barcelona Fira Hotel      35     4.0
# 20                                Hotel Praktik      18     4.5
# 21                             Hotel Porta Fira      27     4.0
# 23                                   Hotel Jazz      21     4.5
# 24                                      B Hotel      14     4.5
# 28                  K+K Hotel Picasso Barcelona      20     4.5
# 32                               Banys Oriental      12     4.5
# ...

# %%
a = df.groupby("postcode")["price range"].value_counts()

# %%
a.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='postcode,price range'>

# %%
data = pd.DataFrame(a)
data
# Out:
#                                            price range
# postcode                      price range
# 08001 Barcelona               Medium-Low             7
#                               Low                    1
# 08002 Barcelona               Medium-High            9
#                               Medium-Low             5
#                               High                   4
#                               Low                    1
# 08003 Barcelona               Medium-Low             4
#                               Medium-High            3
# 08004 Barcelona               Medium-Low             3
# 08005 Barcelona               High                   1
#                               Medium-High            1
#                               Medium-Low             1
# 08006 Barcelona               Medium-Low             1
# 08007 Barcelona               Medium-High            3
#                               Medium-Low             2
# ...

# %%
data.unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='postcode'>

# %%
b = df.groupby("postcode")["rating"].value_counts()

# %%
data2 = pd.DataFrame(b)
data2
# Out:
#                                       rating
# postcode                      rating
# 08001 Barcelona               4.5          6
#                               3.5          1
#                               4.0          1
# 08002 Barcelona               4.5          8
#                               4.0          6
#                               5.0          4
#                               3.5          1
# 08003 Barcelona               4.0          5
#                               4.5          2
#                               5.0          1
# 08004 Barcelona               3.0          1
#                               4.0          1
#                               4.5          1
# 08005 Barcelona               4.0          2
#                               3.5          1
# 08006 Barcelona               4.5          1
# 08007 Barcelona               4.0          3
#                               4.5          2
#                               3.5          1
# ...

# %%
data2.unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='postcode'>

# %%
for_pie = df['price range'].value_counts()
for_pie
# Out:
# Medium-Low     57
# Medium-High    35
# High            9
# Low             3
# Name: price range, dtype: int64

# %%
for_pie.plot.pie(autopct="%.1f%%", subplots = True)
# Out:
# array([<AxesSubplot:ylabel='price range'>], dtype=object)

# %%
postcode2price = df[df["postcode"] == "08002 Barcelona"]["price range"].unique()
postcode2price
# Out:
# array(['Medium-High', 'High', 'Medium-Low', 'Low'], dtype=object)

# %%
postcode2ame = df[df["postcode"] == "08002 Barcelona"]["amenities"].unique()
postcode2ame
# Out:
# array(['Accepts Credit Cards Free Wi-Fi Dogs Not Allowed',
#        'Accepts Credit Cards Free Wi-Fi',
#        'Accepts Credit Cards Free Wi-Fi Dogs Allowed',
#        'Accepts Credit Cards Paid Wi-Fi'], dtype=object)

# %%
postcode2rate = df[df["postcode"] == "08002 Barcelona"]["rating"].unique()
postcode2rate
# Out:
# array([4.5, 5. , 4. , 3.5])

# %%
np.mean(postcode2rate)
# Out:
# 4.25

# %% [raw]
# # postcode2price.plot.pie(autopct="%.1f%%", subplots = True)
#
# # postcode2price.unstack().plot(kind='bar', stacked=True)

# %% [raw]
# data2.plot.pie(autopct="%.1f%%", subplots = True)

# %%
df.rating.hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df.postcode.hist(bins=25)
# Out:
# <AxesSubplot:>

# %%
sns.displot(df["rating"], label = "rating", kde = True)

# %%
sns.displot(df["postcode"], label = "rating", kde = True)

# %%
sns.countplot(x = "rating", data = df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
sns.countplot(y = "postcode", data = df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='postcode'>

# %%
df[df["postcode"] == "08002 Barcelona"]["address"].unique()
# Out:
# array(['La Rambla, 109', 'Passeig de Colom, 9', 'Passeig de Colom, 12',
#        'Plaça Reial, 1', 'Carrer Bergara, 8', 'Avinguda Catedral, 7',
#        'Carrer dels Arcs, 10', "Carrer d'Avinyó, 30", 'La Rambla, 105',
#        'Carrer dels Lledó, 7', 'Carrer dels Capellans, 4',
#        'Carrer de Sant Sever, 5', 'Paseo la Rambla, 138', '117 La Rambla',
#        'Carrer de Riudarenes, 7', 'Plaça del Duc de Medinaceli, 4',
#        'Santa Ana 20', 'Carrer de la Boqueria, 10',
#        'Carrer Sagristans, 13/17'], dtype=object)

# %% [raw]
# df[df["postcode"] == "08002 Barcelona"]["address"].values()

# %% [raw]
# df["reviews"] = df["reviews"].astype(int)
